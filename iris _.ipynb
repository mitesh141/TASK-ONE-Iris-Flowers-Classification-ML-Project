# %% [markdown]
# # Iris Flowers Classification ML Project

# %% [markdown]
# # MITESH PARAB

# %% [markdown]
# STEP1-  import libraries as shown below

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("iris.data", names=["sepal length in cm", "sepal width in cm ","petal length in cm","petal width in cm","class"])

# %% [markdown]
#  Data is displayed

# %%
df.head(10)
# Out:
#    sepal length in cm  sepal width in cm   petal length in cm  \
# 0                 5.1                 3.5                 1.4
# 1                 4.9                 3.0                 1.4
# 2                 4.7                 3.2                 1.3
# 3                 4.6                 3.1                 1.5
# 4                 5.0                 3.6                 1.4
# 5                 5.4                 3.9                 1.7
# 6                 4.6                 3.4                 1.4
# 7                 5.0                 3.4                 1.5
# 8                 4.4                 2.9                 1.4
# 9                 4.9                 3.1                 1.5
#
#    petal width in cm        class
# 0                0.2  Iris-setosa
# 1                0.2  Iris-setosa
# 2                0.2  Iris-setosa
# 3                0.2  Iris-setosa
# 4                0.2  Iris-setosa
# 5                0.4  Iris-setosa
# 6                0.3  Iris-setosa
# ...

# %% [markdown]
# Four features of iris species measured by count, min, mean, max, and percentiles are displayed below.

# %%
df.describe()
# Out:
#        sepal length in cm  sepal width in cm   petal length in cm  \
# count          150.000000          150.000000          150.000000
# mean             5.843333            3.054000            3.758667
# std              0.828066            0.433594            1.764420
# min              4.300000            2.000000            1.000000
# 25%              5.100000            2.800000            1.600000
# 50%              5.800000            3.000000            4.350000
# 75%              6.400000            3.300000            5.100000
# max              7.900000            4.400000            6.900000
#
#        petal width in cm
# count         150.000000
# mean            1.198667
# std             0.763161
# min             0.100000
# 25%             0.300000
# 50%             1.300000
# 75%             1.800000
# max             2.500000

# %% [markdown]
#  Shape of Data

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# The visualization techniques provide imagery representation of Iris species and feature It is used to determine correlations between the X and Y variables

# %%
#Pairwise joint plot (scatter matrix)    
sns.pairplot(df, hue='class', size=3, diag_kind="kde")    
sns.pairplot(df,hue='class')
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Train and validate data

# %%
#dataset spliting  
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %% [markdown]
# Check X ,Y

# %%
x
# Out:
#      sepal length in cm  sepal width in cm   petal length in cm  \
# 0                   5.1                 3.5                 1.4
# 1                   4.9                 3.0                 1.4
# 2                   4.7                 3.2                 1.3
# 3                   4.6                 3.1                 1.5
# 4                   5.0                 3.6                 1.4
# ..                  ...                 ...                 ...
# 145                 6.7                 3.0                 5.2
# 146                 6.3                 2.5                 5.0
# 147                 6.5                 3.0                 5.2
# 148                 6.2                 3.4                 5.4
# 149                 5.9                 3.0                 5.1
#
#      petal width in cm
# 0                  0.2
# 1                  0.2
# 2                  0.2
# 3                  0.2
# 4                  0.2
# ..                 ...
# 145                2.3
# ...

# %%
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: class, Length: 150, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25, random_state=32)

# %% [markdown]
# # Train the model

# %% [markdown]
# RandomForest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
RAM = RandomForestClassifier(n_estimators=4)
RAM.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=4)

# %%
RAM.score(x_test,y_test)
# Out:
# 0.9736842105263158

# %% [markdown]
# Gaussian Naïve Base

# %%
from sklearn.naive_bayes import GaussianNB
GN = GaussianNB()
GN.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
GN.score(x_test,y_test)
# Out:
# 0.9736842105263158

# %% [markdown]
# Support Vector Machine

# %%
from sklearn.svm import SVC
svm = SVC(kernel='rbf')
svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
svm.score(x_test,y_test)
# Out:
# 0.9736842105263158

# %%
predictions = svm.predict(x_test)    
svm.score(x_test, predictions)
# Out:
# 1.0

# %% [markdown]
# # Testing the new data.

# %%
X_new = np.array([[3, 2, 4, 0.2], [  4.7, 3, 1.3, 0.2 ]])    
format(X_new.shape)
# Out:
# '(2, 4)'

# %%
prediction = svm.predict(X_new)   
format(prediction)
# Out:
# "['Iris-versicolor' 'Iris-setosa']"
